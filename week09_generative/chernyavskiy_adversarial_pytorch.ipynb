# %% [markdown]
# ### Generating human faces with Adversarial Networks (10 points)
# <img src="https://www.strangerdimensions.com/wp-content/uploads/2013/11/reception-robot.jpg" width=320>
# This time we'll train a neural net to generate plausible human faces in all their subtlty: appearance, expression, accessories, etc. 'Cuz when us machines gonna take over Earth, there won't be any more faces left. We want to preserve this data for future iterations. Yikes...
#
# Based on https://github.com/Lasagne/Recipes/pull/94 .

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.rcParams.update({'axes.titlesize': 'small'})

from sklearn.datasets import load_digits
#The following line fetches you two datasets: images, usable for autoencoder training and attributes.
#Those attributes will be required for the final part of the assignment (applying smiles), so please keep them in mind
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall20/week08_generative/lfw_dataset.py -O lfw_dataset.py
from lfw_dataset import fetch_lfw_dataset
data,attrs = fetch_lfw_dataset(dimx=36, dimy=36)

#preprocess faces
data = np.float32(data).transpose([0,3,1,2]) / 255.

IMG_SHAPE = data.shape[1:]
# Out:
# --2022-12-17 22:53:40--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall20/week08_generative/lfw_dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3056 (3.0K) [text/plain]
# Saving to: ‘lfw_dataset.py’
#
# lfw_dataset.py      100%[===================>]   2.98K  --.-KB/s    in 0s
#
# 2022-12-17 22:53:40 (49.6 MB/s) - ‘lfw_dataset.py’ saved [3056/3056]
#
# images not found, donwloading...
# extracting...
# done
# attributes not found, downloading...
# done

# %%
#print random image
plt.imshow(data[np.random.randint(data.shape[0])].transpose([1,2,0]),
           cmap="gray", interpolation="none")

# %% [markdown]
# # Generative adversarial nets 101
#
# <img src="https://raw.githubusercontent.com/torch/torch.github.io/master/blog/_posts/images/model.png" width=320px height=240px>
#
# Deep learning is simple, isn't it?
# * build some network that generates the face (small image)
# * make up a __measure__ of __how good that face is__
# * optimize with gradient descent :)
#
#
# The only problem is: how can we engineers tell well-generated faces from bad? And i bet you we won't ask a designer for help.
#
# __If we can't tell good faces from bad, we delegate it to yet another neural network!__
#
# That makes the two of them:
# * __G__enerator - takes random noize for inspiration and tries to generate a face sample.
#   * Let's call him __G__(z), where z is a gaussian noize.
# * __D__iscriminator - takes a face sample and tries to tell if it's great or fake.
#   * Predicts the probability of input image being a __real face__
#   * Let's call him __D__(x), x being an image.
#   * __D(x)__ is a predition for real image and __D(G(z))__ is prediction for the face made by generator.
#
# Before we dive into training them, let's construct the two networks.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()

print("Torch version:", torch.__version__)
if use_cuda:
    print("Using GPU")
else:
    print("Not using GPU")
# Out:
# Torch version: 1.13.0+cu116
# Using GPU

# %%
def sample_noise_batch(batch_size):
    noise = torch.randn(batch_size, CODE_SIZE)
    return noise.cuda() if use_cuda else noise.cpu()
    
class Reshape(nn.Module):
    def __init__(self, shape):
        nn.Module.__init__(self)
        self.shape=shape
    def forward(self,input):
        return input.view(self.shape)

# %%
CODE_SIZE = 256

from itertools import count
# automatic layer name maker. Don't do this in production :)
ix = ('layer_%i'%i for i in count())

generator = nn.Sequential()

generator.add_module(next(ix), nn.Linear(CODE_SIZE, 10*8*8))
generator.add_module(next(ix), nn.ELU())
generator.add_module(next(ix), Reshape([-1, 10, 8, 8]))

generator.add_module(next(ix), nn.ConvTranspose2d(10, 64, kernel_size=(5,5)))
generator.add_module(next(ix), nn.ELU())
generator.add_module(next(ix), nn.ConvTranspose2d(64, 64, kernel_size=(5,5)))
generator.add_module(next(ix), nn.ELU())
generator.add_module(next(ix), nn.Upsample(scale_factor=2))

generator.add_module(next(ix), nn.ConvTranspose2d(64, 32, kernel_size=(5,5)))
generator.add_module(next(ix), nn.ELU())
generator.add_module(next(ix), nn.ConvTranspose2d(32, 32, kernel_size=(5,5)))
generator.add_module(next(ix), nn.ELU())

generator.add_module(next(ix), nn.Conv2d(32, 3, kernel_size=(5,5)))

if use_cuda: generator.cuda()

# %%
generated_data = generator(sample_noise_batch(5))
assert tuple(generated_data.shape)[1:] == IMG_SHAPE, "generator must output an image of shape %s, but instead it produces %s"%(IMG_SHAPE,generated_data.shape)

# %% [markdown]
# ### Discriminator
# * Discriminator is your usual convolutional network with interlooping convolution and pooling layers
# * The network does not include dropout/batchnorm to avoid learning complications.
# * We also regularize the pre-output layer to prevent discriminator from being too certain.

# %%
def sample_data_batch(batch_size):
    idxs = np.random.choice(np.arange(data.shape[0]), size=batch_size)
    batch = torch.tensor(data[idxs], dtype=torch.float32)
    return batch.cuda() if use_cuda else batch.cpu()

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        print(input.shape)
        return input.view(input.shape[0], -1)

# %%
discriminator = nn.Sequential()

### YOUR CODE - create convolutional architecture for discriminator
### Note: please start simple. A few convolutions & poolings would do, inception/resnet is an overkill
ix = ('layer_%i'%i for i in count())

discriminator.add_module(next(ix), nn.Conv2d(3, 8, kernel_size=3, padding=1, stride=1))
discriminator.add_module(next(ix), nn.MaxPool2d(2, stride=2))  # 18
discriminator.add_module(next(ix), nn.Dropout2d(0.1))
discriminator.add_module(next(ix), nn.Conv2d(8, 16, kernel_size=3, padding=1, stride=1))
discriminator.add_module(next(ix), nn.MaxPool2d(2, stride=2))  # 9
# discriminator.add_module(next(ix), nn.Dropout2d(0.1))
# discriminator.add_module(next(ix), nn.LeakyReLU(0.1))

discriminator.add_module(next(ix), nn.Flatten())

discriminator.add_module("disc_logit", nn.Linear(16 * 9 * 9, 1))

if use_cuda: discriminator.cuda()

# %%
discriminator = nn.Sequential()

### YOUR CODE - create convolutional architecture for discriminator
### Note: please start simple. A few convolutions & poolings would do, inception/resnet is an overkill
ix = ('layer_%i'%i for i in count())

discriminator.add_module(next(ix), nn.Conv2d(3, 8, kernel_size=5, padding=2, stride=2))  # 18
discriminator.add_module(next(ix), nn.LeakyReLU(0.1))
discriminator.add_module(next(ix), nn.Dropout2d(0.1))
discriminator.add_module(next(ix), nn.Conv2d(8, 16, kernel_size=5, padding=2, stride=2))  # 9
discriminator.add_module(next(ix), nn.LeakyReLU(0.1))
discriminator.add_module(next(ix), nn.Dropout2d(0.1))
discriminator.add_module(next(ix), nn.Flatten())

discriminator.add_module("disc_logit", nn.Linear(16 * 9 * 9, 1))

if use_cuda: discriminator.cuda()

# %%
discriminator(sample_data_batch(5))
# Out:
# tensor([[-0.0781],
#         [-0.0587],
#         [-0.0838],
#         [-0.0759],
#         [-0.0824]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training
#
# We train the two networks concurrently:
# * Train __discriminator__ to better distinguish real data from __current__ generator
# * Train __generator__ to make discriminator think generator is real
# * Since discriminator is a differentiable neural network, we train both with gradient descent.
#
# ![img](https://s24.postimg.org/cw4nognxx/gan.png)
#
# Training is done iteratively until discriminator is no longer able to find the difference (or until you run out of patience).
#
#
# ### Tricks:
# * Regularize discriminator output weights to prevent explosion
# * Train generator with __adam__ to speed up training. Discriminator trains with SGD to avoid problems with momentum.
# * More: https://github.com/soumith/ganhacks

# %%
def generator_loss(noise):
    """
    1. generate data given noise
    2. compute log P(real | gen noise)
    3. return generator loss (should be scalar)
    """
    generated_data = generator(noise)
    
    disc_on_generated_data = discriminator(generated_data)
    
    logp_gen_is_real = F.logsigmoid(disc_on_generated_data)
    
    loss = -1 * torch.mean(logp_gen_is_real)
    # loss = <generator loss. Mind the sign!>
    
    return loss

# %%
loss = generator_loss(sample_noise_batch(32))

print(loss)

assert len(loss.shape) == 0, "loss must be scalar"
# Out:
# tensor(0.7302, device='cuda:0', grad_fn=<MulBackward0>)

# %%
def discriminator_loss(real_data, generated_data):
    """
    1. compute discriminator's output on real & generated data
    2. compute log-probabilities of real data being real, generated data being fake
    3. return discriminator loss (scalar)
    """
    disc_on_real_data = discriminator(real_data)
    disc_on_fake_data = discriminator(generated_data)
    
    logp_real_is_real = F.logsigmoid(disc_on_real_data)
    logp_gen_is_fake = torch.log(1. - torch.sigmoid(disc_on_fake_data))
    
    loss = -1 * (torch.mean(logp_real_is_real) + torch.mean(logp_gen_is_fake))
    return loss

# %%
loss = discriminator_loss(sample_data_batch(32), 
                   generator(sample_noise_batch(32)))

print(loss)

assert len(loss.shape) == 0, "loss must be scalar"
# Out:
# tensor(1.3901, device='cuda:0', grad_fn=<MulBackward0>)

# %% [markdown]
# ### Auxilary functions
# Here we define a few helper functions that draw current data distributions and sample training batches.

# %%
def sample_images(nrow, ncol, sharp=False):
    images = generator(sample_noise_batch(batch_size=nrow*ncol))
    images = images.data.cpu().numpy().transpose([0, 2, 3, 1])
    if np.var(images)!=0:
        images = images.clip(np.min(data),np.max(data))
    for i in range(nrow*ncol):
        plt.subplot(nrow,ncol,i+1)
        if sharp:
            plt.imshow(images[i], cmap="gray", interpolation="none")
        else:
            plt.imshow(images[i], cmap="gray")
    plt.show()

def sample_probas(batch_size):
    plt.title('Generated vs real data')
    D_real = F.sigmoid(discriminator(sample_data_batch(batch_size)))
    generated_data_batch = generator(sample_noise_batch(batch_size))
    D_fake = F.sigmoid(discriminator(generated_data_batch))
    
    plt.hist(D_real.data.cpu().numpy(),
             label='D(x)', alpha=0.5, range=[0,1])
    plt.hist(D_fake.data.cpu().numpy(),
             label='D(G(z))', alpha=0.5, range=[0,1])
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Training
# Main loop.
# We just train generator and discriminator in a loop and draw results once every N iterations.

# %%
#optimizers
disc_opt = torch.optim.SGD(discriminator.parameters(), lr=5e-3)
gen_opt = torch.optim.Adam(generator.parameters(), lr=1e-4)

# %%
from IPython import display
from tqdm import tnrange
batch_size = 100

for epoch in tnrange(50000):
    
    # Train discriminator
    for i in range(5):
        real_data = sample_data_batch(batch_size)
        fake_data = generator(sample_noise_batch(batch_size))
        loss = discriminator_loss(real_data, fake_data)
        print(loss)
        disc_opt.zero_grad()
        loss.backward()
        disc_opt.step()
        
    # Train generator
    noise = sample_noise_batch(batch_size)
    loss = generator_loss(noise)
    gen_opt.zero_grad()
    loss.backward()
    gen_opt.step()
    
    if epoch %100==0:
        display.clear_output(wait=True)
        sample_images(2,3,True)
        sample_probas(1000)
# Out:
# tensor(1.2766, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3366, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2795, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2892, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2373, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2246, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2727, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2168, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2408, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2299, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2431, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2506, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2221, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2472, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2077, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2293, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2560, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2709, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2110, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1418, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2306, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1813, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1534, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1825, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2078, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2164, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1996, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2107, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2007, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1563, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2191, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2267, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2521, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2992, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2305, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2444, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2878, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2342, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2244, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2458, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3353, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2499, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3301, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2897, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2514, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3327, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2409, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2446, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2797, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1861, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3659, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2662, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3469, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3159, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2815, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3356, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3409, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2857, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2775, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3417, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3352, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3733, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3200, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3673, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2773, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2739, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3866, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2567, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2907, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3023, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2664, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3172, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3082, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3206, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3667, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3118, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3052, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3281, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3411, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2641, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3204, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3029, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3430, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2927, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3226, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2963, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3119, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3001, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3125, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2652, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2396, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2611, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3161, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3011, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3031, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2309, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2802, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2383, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2448, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2816, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2882, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2382, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2231, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2558, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2031, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1738, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2534, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2490, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2619, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2082, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2646, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1811, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1393, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2210, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1968, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2392, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3067, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2836, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2148, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2422, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2342, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2447, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1693, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2538, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2442, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1365, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2092, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2115, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2460, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2324, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2709, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2053, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2238, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1974, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2477, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1418, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2155, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2064, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2374, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2349, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1443, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2048, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2596, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2428, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1068, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2188, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2215, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1530, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2320, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1281, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2127, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2536, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1957, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2043, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3261, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1933, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2032, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2539, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2452, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3471, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2499, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2391, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2446, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2824, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2969, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2187, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.4364, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3602, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3188, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3059, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.4019, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3115, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3014, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3435, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2784, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.4156, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3730, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2630, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3519, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3317, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2895, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3656, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3514, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3654, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2658, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3717, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3353, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3223, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3213, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3332, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2930, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3161, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2772, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2652, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2551, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3017, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3117, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3073, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2465, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2348, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2541, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2524, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3050, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2867, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2840, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3113, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3016, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2569, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1786, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2770, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2465, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1915, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2753, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2111, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2380, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2559, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3064, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2417, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2214, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2973, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2500, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2561, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1983, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3420, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2518, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2480, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1642, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2014, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2517, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1982, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2099, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2207, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2177, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1687, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1685, device='cuda:0', grad_fn=<MulBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-a5245528a489> in <module>
#      12         print(loss)
#      13         disc_opt.zero_grad()
# ---> 14         loss.backward()
#      15         disc_opt.step()
#      16
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=[16, 24])
sample_images(16, 8)

# Note: a no-nonsense neural network should be able to produce reasonably good images after 15k iterations
# By "reasonably good" we mean "resembling a car crash victim" or better

# %% [markdown]
# ### Evaluation
# __The code below__ dumps a batch of images so that you could use them for precision/recall evaluation.
#
# Please, if you want to compare the result with the autoencoder result, generate the same number of images as for autoencoders for a fair comparison.

# %%
num_images = 200
batch_size = 100

all_images = []

for batch_i in range((num_images - 1) / batch_size + 1):
    with torch.no_grad():
        images = generator(sample_noise_batch(batch_size=batch_size))
        images = images.data.cpu().numpy().transpose([0, 2, 3, 1])
    if np.var(images)!=0:
        images = images.clip(np.min(data), np.max(data))
        
    all_images.append(images)
    
all_images = np.concatenate(all_images, axis=0)[:num_images]

np.savez("./gan.npz", Pictures=all_images)
